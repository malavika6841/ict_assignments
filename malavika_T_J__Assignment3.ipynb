# %%
Write a Python function to find the Max of three numbers
# Out:
#   File "/tmp/ipython-input-645410268.py", line 1
#     Write a Python function to find the Max of three numbers
#           ^
# SyntaxError: invalid syntax

# %%
def max_of_three( x, y,):
    if x > y:
        return x
    return y
def max_of_three( x, y,):
    return max_of_two( x, max_of_two( y, z ) )
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# Write a Python function to sum all the numbers in a list.

# %%
def sum_list_builtin(numbers):
  return sum(numbers)

my_list = [18, 12, 30, 10, 7]
total = sum_list_builtin(my_list)
print(f"The sum of {my_list} is: {total}")
# Out:
# The sum of [18, 12, 30, 10, 7] is: 77

# %%
def find_max_builtin(a, b, c):
  return max(a, b, c)
print(find_max_builtin(10, 5, 20))
# Out:
# 20

# %% [markdown]
#  Python program to insert a number to any position in a list (Get the number to be inserted and position from the user)

# %%
l1=[1,2,3,4,5]

# %%
a=int(input("entere the position:"))
b=int(input("enter the number:"))
l1.insert(a,b)
# Out:
# entere the position:5
# enter the number:6

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 4. Write a program to rename a key city to a location in the following dictionary. sample_dict = { "name": "Kelly",  "age":25,  "salary": 8000, "city": "New york"}

# %%
d1={"name": "Kelly",  "age":25,  "salary": 8000, "city": "New york"}
d1['location']=d1.pop('city')
print(d1)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %% [markdown]
# 5. Write a Python program to change Brad’s salary to 8500 in the following dictionary. sample_dict = {     'emp1': {'name': 'Jhon', 'salary': 7500},     'emp2': {'name': 'Emma', 'salary': 8000},     'emp3': {'name': 'Brad', 'salary': 500} } 6

# %%
d2={'emp1': {'name': 'Jhon', 'salary': 7500},
    'emp2': {'name': 'Emma', 'salary': 8000},
    'emp3': {'name': 'Brad', 'salary': 500}
    }
d2['emp3' ]['salary']=8500
print(d2)
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# 6. write a program to copy 44 and 55 from the following tuple into a new tuple.given tuple1=(11,22,33,44,55,66)

# %%
tuple1=(11,22,33,44,55,66)
tuple2=(tuple1[3],tuple1[4])
print(tuple2)
# Out:
# (44, 55)

# %% [markdown]
# 7.counts the number of occurances of item 50 from a tuple tuple=(50,10,60,70,50,58,567,50,81)

# %%
tuple1=(50,10,60,70,50,58,567,50,81)
count=tuple1.count(50)
print(count)
# Out:
# 3
